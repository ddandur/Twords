# %% [markdown]
# ## Collect all tweets from @realDonaldTrump

# %%
import sys
sys.path.append('..')

from twords.twords import Twords 
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
# this pandas line makes the dataframe display all text in a line; useful for seeing entire tweets
pd.set_option('display.max_colwidth', -1)

# %%
twit = Twords()
# set path to folder that contains jar files for twitter search
twit.jar_folder_path = "../jar_files_and_background/"

# %%
twit.get_all_user_tweets("realdonaldtrump", tweets_per_run=500)
# Out:
# Collecting tweets with 500 tweets per run.
# Collecting run 1
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 2
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 3
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 4
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 5
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 6
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 7
# Time to collect 500 tweets: 0.0 minutes
# Tweets timeline incremented by only one day - may need larger tweets_per_run, or could just be regular stutter in querying timeline.
# Collecting run 8
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 9
# Time to collect 500 tweets: 0.2 minutes
# Collecting run 10
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 11
# Time to collect 500 tweets: 0.2 minutes
# Collecting run 12
# Time to collect 500 tweets: 0.2 minutes
# Collecting run 13
# Time to collect 500 tweets: 0.2 minutes
# Collecting run 14
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 15
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 16
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 17
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 18
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 19
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 20
# Time to collect 500 tweets: 0.2 minutes
# Collecting run 21
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 22
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 23
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 24
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 25
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 26
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 27
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 28
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 29
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 30
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 31
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 32
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 33
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 34
# Time to collect 500 tweets: 0.2 minutes
# Collecting run 35
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 36
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 37
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 38
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 39
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 40
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 41
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 42
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 43
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 44
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 45
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 46
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 47
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 48
# Time to collect 500 tweets: 0.2 minutes
# Collecting run 49
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 50
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 51
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 52
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 53
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 54
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 55
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 56
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 57
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 58
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 59
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 60
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 61
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 62
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 63
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 64
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 65
# Time to collect 500 tweets: 0.1 minutes
# Collecting run 66
# Time to collect 500 tweets: 0.0 minutes
# Tweets timeline incremented by only one day - may need larger tweets_per_run, or could just be regular stutter in querying timeline.
# Collecting run 67
# Time to collect 500 tweets: 0.0 minutes
# Total time to collect tweets: 9.0 minutes

# %%
twit.get_java_tweets_from_csv_list()
twit.convert_tweet_dates_to_standard()

# %% [markdown]
# To sort tweets by favorites or retweets, need to convert unicode to integers:

# %%
twit.tweets_df["retweets"] = twit.tweets_df["retweets"].map(int)
twit.tweets_df["favorites"] = twit.tweets_df["favorites"].map(int)

# %%
twit.tweets_df.sort_values("favorites", ascending=False)[:5]
# Out:
# 0     username        date  retweets  favorites  \
# 646    NaN      2016-11-09  220178    632046
# 655    NaN      2016-11-08  343888    572956
# 9760   NaN      2017-01-22  83032     395308
# 9911   NaN      2016-12-31  141383    350082
# 26258  NaN      2016-06-09  164689    292474
#
# 0                                                                                                                                                                                  text  \
# 646    Such a beautiful and important evening! The forgotten man and woman will never be forgotten again. We will all come together as never before
# 655    TODAY WE MAKE AMERICA GREAT AGAIN!
# 9760   Peaceful protests are a hallmark of our democracy. Even if I don't always agree, I recognize the rights of people to express their views.
# 9911   Happy New Year to all, including to my many enemies and those who have fought me and lost so badly they just don't know what to do. Love!
# 26258  How long did it take your staff of 823 people to think that up--and where are your 33,000 emails that you deleted?https://twitter.com/hillaryclinton/status/740973710593654784 …
#
# 0     mentions hashtags                  id  \
# 646    NaN      NaN      796315640307060738
# 655    NaN      NaN      795954831718498305
# 9760   NaN      NaN      823174199036542980
# 9911   NaN      NaN      815185071317676033
# 26258  NaN      NaN      741007091947556864
#
# 0                                                          permalink
# 646    https://twitter.com/realDonaldTrump/status/796315640307060738
# 655    https://twitter.com/realDonaldTrump/status/795954831718498305
# 9760   https://twitter.com/realDonaldTrump/status/823174199036542980
# 9911   https://twitter.com/realDonaldTrump/status/815185071317676033
# 26258  https://twitter.com/realDonaldTrump/status/741007091947556864

# %%
twit.tweets_df.sort_values("retweets", ascending=False)[:5]
# Out:
# 0     username        date  retweets  favorites  \
# 655    NaN      2016-11-08  343888    572956
# 646    NaN      2016-11-09  220178    632046
# 5065   NaN      2014-06-04  177131    146331
# 26258  NaN      2016-06-09  164689    292474
# 15021  NaN      2012-11-06  157054    113664
#
# 0                                                                                                                                                                                  text  \
# 655    TODAY WE MAKE AMERICA GREAT AGAIN!
# 646    Such a beautiful and important evening! The forgotten man and woman will never be forgotten again. We will all come together as never before
# 5065   Are you allowed to impeach a president for gross incompetence?
# 26258  How long did it take your staff of 823 people to think that up--and where are your 33,000 emails that you deleted?https://twitter.com/hillaryclinton/status/740973710593654784 …
# 15021  The electoral college is a disaster for a democracy.
#
# 0     mentions hashtags                  id  \
# 655    NaN      NaN      795954831718498305
# 646    NaN      NaN      796315640307060738
# 5065   NaN      NaN      474134260149157888
# 26258  NaN      NaN      741007091947556864
# 15021  NaN      NaN      266038556504494082
#
# 0                                                          permalink
# 655    https://twitter.com/realDonaldTrump/status/795954831718498305
# 646    https://twitter.com/realDonaldTrump/status/796315640307060738
# 5065   https://twitter.com/realDonaldTrump/status/474134260149157888
# 26258  https://twitter.com/realDonaldTrump/status/741007091947556864
# 15021  https://twitter.com/realDonaldTrump/status/266038556504494082

# %% [markdown]
# For some reason the search did not include Trump's username - random errors like this sometimes happen when querying the twitter website.

# %% [markdown]
# ## Look at word frequencies

# %%
twit.background_path = '../jar_files_and_background/freq_table_72319443_total_words_twitter_corpus.csv'
twit.create_Background_dict()
twit.create_Stop_words()

# %%
twit.lower_tweets()
twit.keep_only_unicode_tweet_text()
twit.remove_urls_from_tweets()
twit.convert_tweet_dates_to_standard()
twit.sort_tweets_by_date()
twit.drop_duplicates_in_text()
# Out:
# Removing urls from tweets...
# This may take a minute - cleaning rate is about 400,000 tweets per minute
# Time to complete: 0.073 minutes
# Tweets cleaned per minute: 433395.4

# %% [markdown]
# Make word frequency dataframe:

# %%
twit.create_word_bag()
twit.make_nltk_object_from_word_bag()
twit.create_word_freq_df(10000)
# Out:
# Time to make words_string:  0.0 minutes
# Time to tokenize:  0.252 minutes
# Time to compute word bag:  0.059 minutes
# Creating word_freq_df...
# Takes about 1 minute per 1000 words
# Time to create word_freq_df:  4.9931 minutes

# %%
twit.word_freq_df.sort_values("log relative frequency", ascending = False, inplace = True)
twit.word_freq_df.head(20)
# Out:
#                    word  occurrences  frequency  relative frequency  \
# 576   turnberry          84           0.000274   1981.871725
# 326   “donald            142          0.000463   1595.384269
# 948   mar-a-lago         52           0.000170   1226.872973
# 984   cpac               51           0.000166   1203.279262
# 622   trumpforpresident  78           0.000254   1150.193412
# 761   melaniatrump       65           0.000212   1095.422297
# 243   doral              173          0.000564   1074.134738
# 1617  traceadkins        29           0.000095   855.272024
# 453   “trump             105          0.000343   799.141825
# 689   karlrove           72           0.000235   772.157815
# 1750  bedminster         26           0.000085   766.795608
# 512   alexsalmond        94           0.000307   764.761667
# 754   squawkcnbc         65           0.000212   730.281531
# 1082  agschneiderman     46           0.000150   723.540471
# 791   omarosa            63           0.000206   675.638088
# 747   mr.trump           66           0.000215   598.917280
# 1464  demdebate          32           0.000104   580.768271
# 534   newsmax_media      91           0.000297   580.277757
# 738   a-rod              67           0.000219   526.926213
# 901   brandiglanville    55           0.000179   447.466933
#
#       log relative frequency  background_occur
# 576   7.591797                10
# 326   7.374870                21
# 948   7.112224                10
# 984   7.092806                10
# 622   7.047685                16
# 761   6.998895                14
# 243   6.979271                38
# 1617  6.751420                8
# 453   6.683538                31
# 689   6.649189                22
# 1750  6.642220                8
# 512   6.639564                29
# 754   6.593430                21
# 1082  6.584156                15
# 791   6.515658                22
# 747   6.395123                26
# 1464  6.364352                13
# 534   6.363507                37
# 738   6.267061                30
# 901   6.103603                29

# %% [markdown]
# ### Look at most and least Trump-like tweets at varying levels of background requirement

# %% [markdown]
# ### At least 100 background occurrences:

# %%
num_words_to_plot = 32
background_cutoff = 100
twit.word_freq_df[twit.word_freq_df["background_occur"]>background_cutoff].sort_values("log relative frequency", ascending=True).set_index("word")["log relative frequency"][-num_words_to_plot:].plot.barh(figsize=(20,
                num_words_to_plot/2.), fontsize=30, color="c"); 
plt.title("log relative frequency", fontsize=30); 
ax = plt.axes();        
ax.xaxis.grid(linewidth=4);

# %% [markdown]
# ### At least 1000 background occurrences:

# %%
num_words_to_plot = 32
background_cutoff = 1000
twit.word_freq_df[twit.word_freq_df["background_occur"]>background_cutoff].sort_values("log relative frequency", ascending=True).set_index("word")["log relative frequency"][-num_words_to_plot:].plot.barh(figsize=(20,
                num_words_to_plot/2.), fontsize=30, color="c"); 
plt.title("log relative frequency", fontsize=30); 
ax = plt.axes();        
ax.xaxis.grid(linewidth=4);

# %% [markdown]
# ### At least 10,000 background occurrences:

# %%
num_words_to_plot = 32
background_cutoff = 10000
twit.word_freq_df[twit.word_freq_df["background_occur"]>background_cutoff].sort_values("log relative frequency", ascending=True).set_index("word")["log relative frequency"][-num_words_to_plot:].plot.barh(figsize=(20,
                num_words_to_plot/2.), fontsize=30, color="c"); 
plt.title("log relative frequency", fontsize=30); 
ax = plt.axes();        
ax.xaxis.grid(linewidth=4);

# %% [markdown]
# ## And now look at least Trump-like relative to Twitter background:

# %%
num_words_to_plot = 32
background_cutoff = 10000
twit.word_freq_df[twit.word_freq_df["background_occur"]>background_cutoff].sort_values("log relative frequency", ascending=False).set_index("word")["log relative frequency"][-num_words_to_plot:].plot.barh(figsize=(20,
                num_words_to_plot/2.), fontsize=30, color="c"); 
plt.title("log relative frequency", fontsize=30); 
ax = plt.axes();        
ax.xaxis.grid(linewidth=4);

# %% [markdown]
# Trump does not post about things happening automatically.

# %%
twit.tweets_containing("fuck")
# Out:
# 20 tweets contain this term
# 0      username  \
# 7311  NaN
# 7905  NaN
# 8424  NaN
# 9128  NaN
# 9246  NaN
# 9961  NaN
# 9963  NaN
# 10035 NaN
# 13100 NaN
# 13970 NaN
# 14157 NaN
# 16558 NaN
# 16672 NaN
# 17403 NaN
# 19298 NaN
# 19430 NaN
# 21495 NaN
# 22754 NaN
# 24183 NaN
# 25265 NaN
#
# 0                                                                                                                                                                             text
# 7311   @benjamin_abey: @realdonaldtrump @mcuban @dallasmavs so? what the fuck is your problem ? the people love him. nobody loves him!"
# 7905   @ironman1021: i think after watching his roast i've realized that @realdonaldtrump is super fucking bad ass props to you sir" true - thanks"
# 8424   @massergio: @realdonaldtrump the fucking truth we need our jobs back!" that won't happen without new leadership!"
# 9128   @twitt_be_cray: @realdonaldtrump go fuck yourself you dumb fuck" when was the last time you had a date-such terrible language (& picture)."
# 9246   @itsjenwbitches: people can hate on @realdonaldtrump all they want, but in reality he's flying his jet over your fucking house as you tweet"
# 9961   @jefepinal: @realdonaldtrump is a fucking genius." true!"
# 9963   @mishaforever: @realdonaldtrump @mikedgarrison fuck yeah! she should have to pay!" she said some really bad and stupid things."
# 10035  @mikomuhfucka: @realdonaldtrump doesn't show enough compassion to ever really be considered a presidential candidate. i have great comp'--"
# 13100  @lloyd156_: @realdonaldtrump doesnt give a fuck, he just tells it like it is lol legend" a very honest person, thanks!"
# 13970  “@realhollishicks so fucking sick of the middle east i agree with trump if we're spending $ over there might as well take their oil";;@realhollishicks;;436241904083431424"
# 14157  @johnnyhabit: @realdonaldtrump why the fuck do i even follow you? because you're addicted to genius, asshole!"
# 16558  @fucksammyy: i want you to be president! @realdonaldtrump" thanks."
# 16672  @fuckceciliaa: @realdonaldtrump i hate to admit it but i'm with you on this one.""
# 17403  every time i speak of the haters and losers i do so with great love and affection. they cannot help the fact that they were born fucked up!
# 19298  @frank_puggi: @realdonaldtrump @realdonaldtrump if one man could get this fucking country back together donald trump can. i admire him.""
# 19430  @fenway315: @realdonaldtrump @apprenticenbc @realgilbert is the fucking man !""
# 21495  @warrenmarcussen: @realdonaldtrump @kbrocking i love your show though donny, i'm a fuckung huge fan" but our country is dieing!"
# 22754  @jsilva74366572: @nicksibrodi vote for trump unless u want to keep getting fucked by isis, china, lobbyists and everyone else""
# 24183  @mannamalistic: i'm s lifelong liberal and have come to fucking love @realdonaldtrump. he speaks the truth!""
# 25265  @muhfuck: @berniesanders donald trump is the only candidate for middle class america @realdonaldtrump #trump2016 #makeamericagreatagain""
